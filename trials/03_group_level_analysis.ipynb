# %%
import mne
from os.path import isfile, join
from os import listdir
import numpy as np
import statistics
from mne.decoding import Vectorizer

from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import cross_val_score, train_test_split, GridSearchCV, StratifiedKFold, cross_val_predict
from sklearn.metrics import precision_recall_fscore_support, accuracy_score

from scipy import stats

# Models
from sklearn import svm
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.linear_model import LogisticRegression

# %%
files
# Out:
# ['epoch_data/aq values deu neg.fif',
#  'epoch_data/ck values deu thr.fif',
#  'epoch_data/dm values deu thr.fif',
#  'epoch_data/dm2 values eng thr.fif',
#  'epoch_data/ds values eng thr.fif',
#  'epoch_data/dz value eng neu.fif',
#  'epoch_data/ER valuess eng thr.fif',
#  'epoch_data/EY values eng neu.fif',
#  'epoch_data/gg valuess deu thr.fif',
#  'epoch_data/gl values deu thr.fif',
#  'epoch_data/kr values deu neg.fif',
#  'epoch_data/ks values deu neg.fif',
#  'epoch_data/LH valuess eng neg.fif',
#  'epoch_data/mc values deu neg.fif',
#  'epoch_data/mm2 values eng neg.fif',
#  'epoch_data/ns values eng neu.fif',
#  'epoch_data/og valuess de neu.fif',
#  'epoch_data/rt values eng neg.fif',
#  'epoch_data/tp values eng neu.fif',
#  'epoch_data/vs values eng neg.fif',
#  'epoch_data/yl values eng thr.fif']

# %%
len(data_folder)+2/-4
# Out:
# 34.5

# %%
[int(f[(len(data_folder)+2):-4]) for f in files]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 [int(f[(len(data_folder)+2):-4]) for f in files]
#
# ValueError: invalid literal for int() with base 10: 'udy1_EEG_P-01_FN_Trial-001'

# %%
data_folder = 'epoch_data/'
#data_folder = 'C:/Users/serha/Downloads/study1_eeg'
files = [data_folder+f for f in listdir(data_folder) if isfile(join(data_folder, f)) and '.DS_Store' not in f]

#extract ids from file names
ids = [int(f[(len(data_folder)+2):-4]) for f in files]

epochs = [mne.read_epochs(f, verbose='error') for f in files]
epochs_UN = [e['FU', 'FN'] for e in epochs]
epochs_UP = [e['FU', 'FP'] for e in epochs]
epochs_NP = [e['FN', 'FP'] for e in epochs]
# Dataset with unpleasant and neutral events
data_UN = [e.get_data() for e in epochs_UN]
labels_UN = [e.events[:,-1] for e in epochs_UN]

data_UP = [e.get_data() for e in epochs_UP]
labels_UP = [e.events[:,-1] for e in epochs_UP]

data_NP = [e.get_data() for e in epochs_NP]
labels_NP = [e.events[:,-1] for e in epochs_NP]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 6
#       3 files = [data_folder+f for f in listdir(data_folder) if isfile(join(data_folder, f)) and '.DS_Store' not in f]
#       5 #extract ids from file names
# ----> 6 ids = [int(f[(len(data_folder)+2):-4]) for f in files]
#       8 epochs = [mne.read_epochs(f, verbose='error') for f in files]
#       9 epochs_UN = [e['FU', 'FN'] for e in epochs]
#
# ValueError: invalid literal for int() with base 10: ' values deu neg'
