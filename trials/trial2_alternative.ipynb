# %%
import os
import numpy as np
import matplotlib.pyplot as plt

import mne
from mne import io
#from mne.datasets import sample
from mne.minimum_norm import compute_source_psd, read_inverse_operator

# %%
root = ("E:\\PhD\\materials_neuroscience\\trials\\VAL_KLAUS")
list_file_names = []
for path, dirs, files in os.walk(root):
    for file in files:
        if file.endswith(".bdf"):
             list_file_names.append(os.path.join(root, file))
print(len(list_file_names),'files')
for i in list_file_names:
    print(i[47:])
# Out:
# 21 files
# aq values deu neg.bdf
# ck values deu thr.bdf
# dm values deu thr.bdf
# dm2 values eng thr.bdf
# ds values eng thr.bdf
# dz value eng neu.bdf
# ER valuess eng thr.bdf
# EY values eng neu.bdf
# gg valuess deu thr.bdf
# gl values deu thr.bdf
# kr values deu neg.bdf
# ks values deu neg.bdf
# LH valuess eng neg.bdf
# mc values deu neg.bdf
# mm2 values eng neg.bdf
# ns values eng neu.bdf
# og valuess de neu.bdf
# rt values eng neg.bdf
# tp values eng neu.bdf
# vs values eng neg.bdf
# yl values eng thr.bdf

# %%
list_raws = []
for item in list_file_names:
    raw = mne.io.read_raw_bdf(item)
    list_raws.append(raw.pick_types(meg=False, eeg=True, eog=False, exclude='bads'))
# Out:
# Extracting EDF parameters from E:\PhD\materials_neuroscience\trials\VAL_KLAUS\aq values deu neg.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Extracting EDF parameters from E:\PhD\materials_neuroscience\trials\VAL_KLAUS\ck values deu thr.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Extracting EDF parameters from E:\PhD\materials_neuroscience\trials\VAL_KLAUS\dm values deu thr.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Extracting EDF parameters from E:\PhD\materials_neuroscience\trials\VAL_KLAUS\dm2 values eng thr.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Extracting EDF parameters from E:\PhD\materials_neuroscience\trials\VAL_KLAUS\ds values eng thr.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Extracting EDF parameters from E:\PhD\materials_neuroscience\trials\VAL_KLAUS\dz value eng neu.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Extracting EDF parameters from E:\PhD\materials_neuroscience\trials\VAL_KLAUS\ER valuess eng thr.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Extracting EDF parameters from E:\PhD\materials_neuroscience\trials\VAL_KLAUS\EY values eng neu.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Extracting EDF parameters from E:\PhD\materials_neuroscience\trials\VAL_KLAUS\gg valuess deu thr.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Extracting EDF parameters from E:\PhD\materials_neuroscience\trials\VAL_KLAUS\gl values deu thr.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Extracting EDF parameters from E:\PhD\materials_neuroscience\trials\VAL_KLAUS\kr values deu neg.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Extracting EDF parameters from E:\PhD\materials_neuroscience\trials\VAL_KLAUS\ks values deu neg.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Extracting EDF parameters from E:\PhD\materials_neuroscience\trials\VAL_KLAUS\LH valuess eng neg.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Extracting EDF parameters from E:\PhD\materials_neuroscience\trials\VAL_KLAUS\mc values deu neg.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Extracting EDF parameters from E:\PhD\materials_neuroscience\trials\VAL_KLAUS\mm2 values eng neg.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Extracting EDF parameters from E:\PhD\materials_neuroscience\trials\VAL_KLAUS\ns values eng neu.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Extracting EDF parameters from E:\PhD\materials_neuroscience\trials\VAL_KLAUS\og valuess de neu.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Extracting EDF parameters from E:\PhD\materials_neuroscience\trials\VAL_KLAUS\rt values eng neg.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Extracting EDF parameters from E:\PhD\materials_neuroscience\trials\VAL_KLAUS\tp values eng neu.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Extracting EDF parameters from E:\PhD\materials_neuroscience\trials\VAL_KLAUS\vs values eng neg.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).
# Extracting EDF parameters from E:\PhD\materials_neuroscience\trials\VAL_KLAUS\yl values eng thr.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# NOTE: pick_types() is a legacy function. New code should use inst.pick(...).

# %%
for i in list_raws:
    print(i.info)
# Out:
# <Info | 8 non-empty values
#  bads: []
#  ch_names: Fp1, AF3, F7, F3, FC1, FC5, T7, C3, CP1, CP5, P7, P3, Pz, PO3, ...
#  chs: 40 EEG
#  custom_ref_applied: False
#  highpass: 0.0 Hz
#  lowpass: 417.0 Hz
#  meas_date: 2002-01-09 06:58:59 UTC
#  nchan: 40
#  projs: []
#  sfreq: 2048.0 Hz
#  subject_info: 3 items (dict)
# >
# <Info | 8 non-empty values
#  bads: []
#  ch_names: Fp1, AF3, F7, F3, FC1, FC5, T7, C3, CP1, CP5, P7, P3, Pz, PO3, ...
#  chs: 40 EEG
#  custom_ref_applied: False
#  highpass: 0.0 Hz
#  lowpass: 417.0 Hz
#  meas_date: 2017-04-01 14:24:53 UTC
#  nchan: 40
#  projs: []
#  sfreq: 2048.0 Hz
#  subject_info: 3 items (dict)
# >
# <Info | 8 non-empty values
#  bads: []
#  ch_names: Fp1, AF3, F7, F3, FC1, FC5, T7, C3, CP1, CP5, P7, P3, Pz, PO3, ...
#  chs: 40 EEG
#  custom_ref_applied: False
#  highpass: 0.0 Hz
#  lowpass: 417.0 Hz
#  meas_date: 2017-03-30 11:51:10 UTC
#  nchan: 40
#  projs: []
#  sfreq: 2048.0 Hz
#  subject_info: 3 items (dict)
# >
# <Info | 8 non-empty values
#  bads: []
#  ch_names: Fp1, AF3, F7, F3, FC1, FC5, T7, C3, CP1, CP5, P7, P3, Pz, PO3, ...
#  chs: 40 EEG
#  custom_ref_applied: False
#  highpass: 0.0 Hz
#  lowpass: 417.0 Hz
#  meas_date: 2017-04-05 09:20:51 UTC
#  nchan: 40
#  projs: []
#  sfreq: 2048.0 Hz
#  subject_info: 1 item (dict)
# >
# <Info | 8 non-empty values
#  bads: []
#  ch_names: Fp1, AF3, F7, F3, FC1, FC5, T7, C3, CP1, CP5, P7, P3, Pz, PO3, ...
#  chs: 40 EEG
#  custom_ref_applied: False
#  highpass: 0.0 Hz
#  lowpass: 417.0 Hz
#  meas_date: 2017-05-05 13:25:15 UTC
#  nchan: 40
#  projs: []
#  sfreq: 2048.0 Hz
#  subject_info: 1 item (dict)
# >
# <Info | 8 non-empty values
#  bads: []
#  ch_names: Fp1, AF3, F7, F3, FC1, FC5, T7, C3, CP1, CP5, P7, P3, Pz, PO3, ...
#  chs: 40 EEG
#  custom_ref_applied: False
#  highpass: 0.0 Hz
#  lowpass: 417.0 Hz
#  meas_date: 2017-04-03 18:25:59 UTC
#  nchan: 40
#  projs: []
#  sfreq: 2048.0 Hz
#  subject_info: 3 items (dict)
# >
# <Info | 8 non-empty values
#  bads: []
#  ch_names: Fp1, AF3, F7, F3, FC1, FC5, T7, C3, CP1, CP5, P7, P3, Pz, PO3, ...
#  chs: 40 EEG
#  custom_ref_applied: False
#  highpass: 0.0 Hz
#  lowpass: 417.0 Hz
#  meas_date: 2017-05-18 18:49:21 UTC
#  nchan: 40
#  projs: []
#  sfreq: 2048.0 Hz
#  subject_info: 3 items (dict)
# >
# <Info | 8 non-empty values
#  bads: []
#  ch_names: Fp1, AF3, F7, F3, FC1, FC5, T7, C3, CP1, CP5, P7, P3, Pz, PO3, ...
#  chs: 40 EEG
#  custom_ref_applied: False
#  highpass: 0.0 Hz
#  lowpass: 417.0 Hz
#  meas_date: 2017-03-26 12:44:41 UTC
#  nchan: 40
#  projs: []
#  sfreq: 2048.0 Hz
#  subject_info: 3 items (dict)
# >
# <Info | 8 non-empty values
#  bads: []
#  ch_names: Fp1, AF3, F7, F3, FC1, FC5, T7, C3, CP1, CP5, P7, P3, Pz, PO3, ...
#  chs: 40 EEG
#  custom_ref_applied: False
#  highpass: 0.0 Hz
#  lowpass: 417.0 Hz
#  meas_date: 2017-05-04 13:29:21 UTC
#  nchan: 40
#  projs: []
#  sfreq: 2048.0 Hz
#  subject_info: 3 items (dict)
# >
# <Info | 8 non-empty values
#  bads: []
#  ch_names: Fp1, AF3, F7, F3, FC1, FC5, T7, C3, CP1, CP5, P7, P3, Pz, PO3, ...
#  chs: 40 EEG
#  custom_ref_applied: False
#  highpass: 0.0 Hz
#  lowpass: 417.0 Hz
#  meas_date: 2017-03-20 15:57:35 UTC
#  nchan: 40
#  projs: []
#  sfreq: 2048.0 Hz
#  subject_info: 3 items (dict)
# >
# <Info | 8 non-empty values
#  bads: []
#  ch_names: Fp1, AF3, F7, F3, FC1, FC5, T7, C3, CP1, CP5, P7, P3, Pz, PO3, ...
#  chs: 40 EEG
#  custom_ref_applied: False
#  highpass: 0.0 Hz
#  lowpass: 417.0 Hz
#  meas_date: 2017-05-17 10:41:58 UTC
#  nchan: 40
#  projs: []
#  sfreq: 2048.0 Hz
#  subject_info: 3 items (dict)
# >
# <Info | 8 non-empty values
#  bads: []
#  ch_names: Fp1, AF3, F7, F3, FC1, FC5, T7, C3, CP1, CP5, P7, P3, Pz, PO3, ...
#  chs: 40 EEG
#  custom_ref_applied: False
#  highpass: 0.0 Hz
#  lowpass: 417.0 Hz
#  meas_date: 2017-03-20 17:45:18 UTC
#  nchan: 40
#  projs: []
#  sfreq: 2048.0 Hz
#  subject_info: 3 items (dict)
# >
# <Info | 8 non-empty values
#  bads: []
#  ch_names: Fp1, AF3, F7, F3, FC1, FC5, T7, C3, CP1, CP5, P7, P3, Pz, PO3, ...
#  chs: 40 EEG
#  custom_ref_applied: False
#  highpass: 0.0 Hz
#  lowpass: 417.0 Hz
#  meas_date: 2017-05-15 16:00:48 UTC
#  nchan: 40
#  projs: []
#  sfreq: 2048.0 Hz
#  subject_info: 3 items (dict)
# >
# <Info | 8 non-empty values
#  bads: []
#  ch_names: Fp1, AF3, F7, F3, FC1, FC5, T7, C3, CP1, CP5, P7, P3, Pz, PO3, ...
#  chs: 40 EEG
#  custom_ref_applied: False
#  highpass: 0.0 Hz
#  lowpass: 417.0 Hz
#  meas_date: 2017-04-04 10:31:31 UTC
#  nchan: 40
#  projs: []
#  sfreq: 2048.0 Hz
#  subject_info: 3 items (dict)
# >
# <Info | 8 non-empty values
#  bads: []
#  ch_names: Fp1, AF3, F7, F3, FC1, FC5, T7, C3, CP1, CP5, P7, P3, Pz, PO3, ...
#  chs: 40 EEG
#  custom_ref_applied: False
#  highpass: 0.0 Hz
#  lowpass: 417.0 Hz
#  meas_date: 2017-04-03 11:18:57 UTC
#  nchan: 40
#  projs: []
#  sfreq: 2048.0 Hz
#  subject_info: 3 items (dict)
# >
# <Info | 8 non-empty values
#  bads: []
#  ch_names: Fp1, AF3, F7, F3, FC1, FC5, T7, C3, CP1, CP5, P7, P3, Pz, PO3, ...
#  chs: 40 EEG
#  custom_ref_applied: False
#  highpass: 0.0 Hz
#  lowpass: 417.0 Hz
#  meas_date: 2017-05-18 13:15:20 UTC
#  nchan: 40
#  projs: []
#  sfreq: 2048.0 Hz
#  subject_info: 1 item (dict)
# >
# <Info | 8 non-empty values
#  bads: []
#  ch_names: Fp1, AF3, F7, F3, FC1, FC5, T7, C3, CP1, CP5, P7, P3, Pz, PO3, ...
#  chs: 40 EEG
#  custom_ref_applied: False
#  highpass: 0.0 Hz
#  lowpass: 417.0 Hz
#  meas_date: 2017-03-29 13:40:54 UTC
#  nchan: 40
#  projs: []
#  sfreq: 2048.0 Hz
#  subject_info: 1 item (dict)
# >
# <Info | 8 non-empty values
#  bads: []
#  ch_names: Fp1, AF3, F7, F3, FC1, FC5, T7, C3, CP1, CP5, P7, P3, Pz, PO3, ...
#  chs: 40 EEG
#  custom_ref_applied: False
#  highpass: 0.0 Hz
#  lowpass: 417.0 Hz
#  meas_date: 2017-03-24 11:05:19 UTC
#  nchan: 40
#  projs: []
#  sfreq: 2048.0 Hz
#  subject_info: 1 item (dict)
# >
# <Info | 8 non-empty values
#  bads: []
#  ch_names: Fp1, AF3, F7, F3, FC1, FC5, T7, C3, CP1, CP5, P7, P3, Pz, PO3, ...
#  chs: 40 EEG
#  custom_ref_applied: False
#  highpass: 0.0 Hz
#  lowpass: 417.0 Hz
#  meas_date: 2017-04-07 10:32:49 UTC
#  nchan: 40
#  projs: []
#  sfreq: 2048.0 Hz
#  subject_info: 1 item (dict)
# >
# <Info | 8 non-empty values
#  bads: []
#  ch_names: Fp1, AF3, F7, F3, FC1, FC5, T7, C3, CP1, CP5, P7, P3, Pz, PO3, ...
#  chs: 40 EEG
#  custom_ref_applied: False
#  highpass: 0.0 Hz
#  lowpass: 417.0 Hz
#  meas_date: 2017-05-09 14:58:06 UTC
#  nchan: 40
#  projs: []
#  sfreq: 2048.0 Hz
#  subject_info: 3 items (dict)
# >
# <Info | 8 non-empty values
#  bads: []
#  ch_names: Fp1, AF3, F7, F3, FC1, FC5, T7, C3, CP1, CP5, P7, P3, Pz, PO3, ...
#  chs: 40 EEG
#  custom_ref_applied: False
#  highpass: 0.0 Hz
#  lowpass: 417.0 Hz
#  meas_date: 2017-04-03 14:00:15 UTC
#  nchan: 40
#  projs: []
#  sfreq: 2048.0 Hz
#  subject_info: 3 items (dict)
# >

# %%
#for i in list_raws:
#    print(i.info['subject_info'])
#list_raws[0].info['subject_info']

#raw.crop(0, 60) # keeps the first minute of data and discards the rest
#for item in list_raws:
#    item.plot()
#list_raws[0].plot(n_channels=32)

# %%
list_raws[0].plot_psd()
# Out:
# NOTE: plot_psd() is a legacy function. New code should use .compute_psd().plot().
# Effective window size : 1.000 (s)
# C:\Users\serko\AppData\Local\Temp\ipykernel_5444\4216418254.py:1: RuntimeWarning: Channel locations not available. Disabling spatial colors.
#   list_raws[0].plot_psd()
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# <MNELineFigure size 1000x350 with 1 Axes>
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# %matplotlib widget
test.compute_psd(fmax=50).plot(picks="data", exclude="bads")
test.plot(duration=4, n_channels=32)
# Out:
# Effective window size : 1.000 (s)
# C:\Users\serko\AppData\Local\Temp\ipykernel_5444\3779271491.py:2: RuntimeWarning: Channel locations not available. Disabling spatial colors.
#   test.compute_psd(fmax=50).plot(picks="data", exclude="bads")
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# <MNEBrowseFigure size 800x800 with 4 Axes>
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
