# %%
import pyedflib
import numpy as np

# %%
file_name = pyedflib.data.get_generator_filename()
f = pyedflib.EdfReader('VAL_KLAUS/ks values deu neg.bdf')
n = f.signals_in_file
signal_labels = f.getSignalLabels()
sigbufs = np.zeros((n, f.getNSamples()[0]))
for i in np.arange(n):
        sigbufs[i, :] = f.readSignal(i)

# %%
print(len(sigbufs))
len(sigbufs[40])
# Out:
# 41
# 890880

# %%
file_name = pyedflib.data.get_generator_filename()
f = pyedflib.EdfReader('VAL_KLAUS/dm values deu thr.bdf')
n = f.signals_in_file
signal_labels = f.getSignalLabels()
sigbufs = np.zeros((n, f.getNSamples()[0]))
for i in np.arange(n):
        sigbufs[i, :] = f.readSignal(i)

# %%
print(len(sigbufs))
len(sigbufs[40])
# Out:
# 41
# 710656

# %%
file_name = pyedflib.data.get_generator_filename()
f = pyedflib.EdfReader('VAL_KLAUS/gl values deu thr.bdf')
n = f.signals_in_file
signal_labels = f.getSignalLabels()
sigbufs = np.zeros((n, f.getNSamples()[0]))
for i in np.arange(n):
        sigbufs[i, :] = f.readSignal(i)

# %%
print(len(sigbufs))
len(sigbufs[40])
# Out:
# 41
# 858112

# %%
sigbufs
# Out:
# array([[-9.73084140e+03, -9.75759135e+03, -9.75134136e+03, ...,
#         -8.87684297e+03, -8.86981174e+03, -8.86493675e+03],
#        [-1.02412780e+04, -1.02654654e+04, -1.02560904e+04, ...,
#         -9.02724895e+03, -9.01999896e+03, -9.01515522e+03],
#        [-6.72169071e+03, -6.75219065e+03, -6.74928440e+03, ...,
#         -5.74113002e+03, -5.73253628e+03, -5.72631755e+03],
#        ...,
#        [-2.58720538e+05, -2.58720506e+05, -2.58720850e+05, ...,
#         -2.58718444e+05, -2.58718069e+05, -2.58717850e+05],
#        [-2.58716319e+05, -2.58716569e+05, -2.58716881e+05, ...,
#         -2.58714381e+05, -2.58714444e+05, -2.58714225e+05],
#        [-6.35699200e+06, -6.35699200e+06, -6.35699200e+06, ...,
#         -6.42252800e+06, -6.42252800e+06, -6.42252800e+06]])
